# %%
lookto = '/home/lscsc/caizhijie/0420-wamera-benchmark/annotate_29/3c.pk'

import pickle as pk

df = pk.load(open(lookto, 'rb'))

# %%
n = 8

for k in range(n):
    df_ = df[k * int(len(df) / n) : (k+1) * (int(len(df) / n))]
    
    pk.dump(df_, open('/home/lscsc/caizhijie/0710-falldewideo/annotate/csi/data/3c_%d.pk' % k, 'wb'))

# %%
df_
# Out:
#                                                      csi  \
# 63000  [[[[-1.11920126+1.11920126j  2.23840251+2.7980...
# 63001  [[[[-1.67880186+1.11920124j  1.67880186+2.7980...
# 63002  [[[[0.55960062+1.67880185j 2.79800309-0.559600...
# 63003  [[[[-1.11920123-1.11920123j -2.79800308+2.7980...
# 63004  [[[[ 1.11920122+0.55960061j  2.23840244-2.2384...
# ...                                                  ...
# 71995  [[[[-2.23840256-0.55960064j -1.11920128+2.7980...
# 71996  [[[[-1.67880193+0.j          0.        +2.7980...
# 71997  [[[[-2.23840257+0.55960064j  0.55960064+2.7980...
# 71998  [[[[ 1.67880193+1.67880193j  2.23840257-2.2384...
# 71999  [[[[ 1.67880193+1.11920128j  1.11920128-2.7980...
#
#                                                      pic
# 63000  /home/sensing/caizhijie/0702-falldewideo/data/...
# 63001  /home/sensing/caizhijie/0702-falldewideo/data/...
# 63002  /home/sensing/caizhijie/0702-falldewideo/data/...
# 63003  /home/sensing/caizhijie/0702-falldewideo/data/...
# 63004  /home/sensing/caizhijie/0702-falldewideo/data/...
# ...                                                  ...
# 71995  /home/sensing/caizhijie/0702-falldewideo/data/...
# 71996  /home/sensing/caizhijie/0702-falldewideo/data/...
# 71997  /home/sensing/caizhijie/0702-falldewideo/data/...
# 71998  /home/sensing/caizhijie/0702-falldewideo/data/...
# 71999  /home/sensing/caizhijie/0702-falldewideo/data/...
#
# [9000 rows x 2 columns]
